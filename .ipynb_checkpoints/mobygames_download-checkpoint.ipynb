# %% [markdown]
# # Import Libraries

# %%
import glob
import time
import timeit
import pickle
import requests
import json
import re
import numpy as np
import pandas as pd
from multiprocessing import Pool
from matplotlib import pyplot as plt
from zipfile import ZipFile
import lxml.etree as etree
import xmlschema
from pprint import pprint
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from itertools import combinations
from matplotlib.patches import Patch
import distinctipy

# If 'get_career' is a custom module you've created, keep this import

# Define 'toc' function once
def toc(start_time):
    elapsed = timeit.default_timer() - start_time
    print(elapsed)

# Record start time
start_time = timeit.default_timer()
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import matplotlib.gridspec as gridspec

import math
import requests
from bs4 import BeautifulSoup
import matplotlib as mpl
import seaborn as sns
import matplotlib.cm as cm
import pickle
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.transforms as mtransforms
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
sns.set_context('talk')#, font_scale=1.5)
mpl.rcParams.update({'text.usetex': False})
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
path_career='/mnt/sdb1/sandeep/000game_dev/'
path_data='/mnt/sdb1/sandeep/000game_dev/data/'

# GB_INLCUDED_OR_NOT='GB_NOT_INCLUDED'

# %%
# Initialize a list to hold game details
game_links=[]
pagelist=[x for x in range(5)]+[x for x in range(10,15)]+[x for x in range(30,35)]
for page in pagelist:
    print(page,end='\r')
    # URL of the page to scrape
    url = "https://www.mobygames.com/game/platform:windows/sort:moby_score/page:"+str(page)+"/"
    response = requests.get(url)

    # Check if the request was successful
    if response.status_code == 200:
        # Parse the content of the page
        soup = BeautifulSoup(response.content, 'html.parser')
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
    link_start='https://www.mobygames.com/game/'
    import re
    X=str(response.content)
    res = [i for i in range(len(X)) if X.startswith(link_start, i)]
    for it in range(7,18+7):
        game_links.append(X[res[it]:res[it]+200].split(',')[0][0:-1])
game_links=np.unique(game_links)
# Out:
# 34

# %%
# len(res)
# game_links=[]

# for it in range(0,len(res)):
#     game_links.append(X[res[it]:res[it]+200].split(',')[0][0:-1])
len(game_links)
# Out:
# 162

# %% [markdown]
# # Parallel scraping

# %%
import requests
from bs4 import BeautifulSoup
from concurrent.futures import ThreadPoolExecutor, as_completed

def fetch_and_parse(url):
    """
    Fetches the content of the given URL and parses it with BeautifulSoup.
    Returns a BeautifulSoup object or None if the request fails.
    """
    response = requests.get(url)
    if response.status_code == 200:
        return BeautifulSoup(response.content, 'html.parser')
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return None

# %% [markdown]
# # download credits of game

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import time

total_urls = len(game_links)
processed_urls = 0
gamesoup_dict = {}  # Dictionary to store game link and corresponding soup

# Function to fetch and parse the content of the URL
def fetch_and_parse_url(url):
    """
    Fetches the content of the given URL and parses it with BeautifulSoup.
    Returns a BeautifulSoup object or None if the request fails.
    """
    response = requests.get(url)
    if response.status_code == 200:
        return url,BeautifulSoup(response.content, 'html.parser')
    else:
        print(f"Failed to retrieve the webpage. Status code: {response.status_code}")
        return None

# Function to process a batch of URLs
def process_batch(urls):
    global processed_urls
    with ThreadPoolExecutor(max_workers=5) as executor:
        future_to_url = {executor.submit(fetch_and_parse_url, url+'credits/windows/'): url for url in urls}

        for future in as_completed(future_to_url):
            url, soup = future.result()
            processed_urls += 1
            if soup:
                gamesoup_dict[url] = soup  # Store in dictionary with URL as key
            print(f"Processed {processed_urls}/{total_urls} URLs", end='\r')

# Split game_links into smaller lists of 50 links
batch_size = 50
game_links_batches = [game_links[i:i + batch_size] for i in range(0, len(game_links), batch_size)]

# Process each batch sequentially
for batch in game_links_batches:
    process_batch(batch)
    time.sleep(5)  # Wait for 5 seconds before processing the next batch
# Out:
# Processed 162/162 URLs

# %% [markdown]
# ## save collected credits of the games

# %%
# gamesoup_str=[str(x) for x in gamesoup]
# with open(path_data+'00gamesoup_str.pkl', 'wb') as f:
#     pickle.dump(gamesoup_str, f)

# %%
with open(path_career+'gamesoup_str.pkl', 'rb') as f:
    gamesoup_str=pickle.load(f)
gamesoup = [BeautifulSoup(html_string, 'html.parser') for html_string in gamesoup_str  ]

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed

# def process_soup(it, gamesoup, game_links):
#     soup = gamesoup[it]
#     game = game_links[it]
#     td_elements = soup.find_all('td')
#     loc_td = []
#     hrefs = []
#     roles = []
#     for td_element in td_elements:
#         a_tags = td_element.find_all('a')
#         link_start = str(td_element)
# #         loc_td.append([i for i in range(len(X)) if X.startswith(link_start, i)])
#         hrefs.append([a.get('href') for a in a_tags])
#         roles.append(td_element.get_text().strip())
#     return game, [roles, hrefs]
def SouptoRoles(gamesoup_dict, game_links):
    game_to_priorlinks={}
    RolesAndPeople={}
    for it in range(len(gamesoup_dict)):
        print(it/len(gamesoup_dict),end='\r')
        game,soup = list(gamesoup_dict.items())[it]

        td_elements = soup.find_all('td')
        hrefs = []
        roles = []

        for td_element in td_elements:
            # Extract 'a' tags, assuming they are direct children of 'td' elements
            a_tags = td_element.find_all('a')
            # Extract href attributes
            hrefs.append([a.get('href') for a in a_tags])
            # Extract text directly
            roles.append(td_element.get_text(strip=True))
        game_to_priorlinks[game]=[roles, hrefs]
        
        RolesAndPeople[game]={r:h for r,h in zip(roles[0::2],hrefs[1::2])}

    return game_to_priorlinks,RolesAndPeople

game_to_priorlinks,RolesAndPeople=SouptoRoles(gamesoup_dict, game_links)
# Out:
# 0.993827160493827134

# %%
it=5
game,soup = list(gamesoup_dict.items())[it]
game
# Out:
# 'https://www.mobygames.com/game/117263/gris/credits/windows/'

# %%
# game_to_priorlinks

# %% [markdown]
# # download prior collabs
# small teams only

# %%
list(game_to_priorlinks.items())[5]

# %% [markdown]
# ## isolate small teams <100 members

# %%
teamsizes={}
small_teams={}
for game,Roles in RolesAndPeople.items():
#     print()
    roles=list(Roles.values())
    if len(roles)>0:
        members=np.concatenate(roles)
    else:
        members=[]
    teamsizes[game]=len(members)
    if len(members)<=100:
        small_teams[game]=Roles

# %%
with open(path_data+'small_teams.pkl', 'wb') as f:
    pickle.dump(small_teams, f)

# %% [markdown]
# ## plot: Team Sizes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Categorize team sizes
categories = {'Small': 0, 'Medium': 0, 'Large': 0}
for size in teamsizes.values():
    if size < 150:
        categories['Small'] += 1
    elif 150 <= size < 400:
        categories['Medium'] += 1
    else:
        categories['Large'] += 1

# Create a bar chart
sns.barplot(x=list(categories.keys()), y=list(categories.values()))

plt.title('Team Size Categories')
plt.xlabel('Team Size')
plt.ylabel('Frequency')
plt.show()

# %%
# teamsizes={}
# for game,Roles in RolesAndPeople.items():
# #     print()
#     roles=list(Roles.values())
#     if len(roles)>0:
#         members=np.concatenate(roles)
#     else:
#         members=[]
#     teamsizes[game]=len(members)
# #     print(game, len(members))
# #     hrefs=hrefs[1::2]
# #     teamsize=len(hrefs)
# # #     if teamsize<200 and teamsize>0:
# #     if teamsize<1000 and teamsize>0:
# #     #     print(x[1][1])
# #         print(x[0],teamsize)

# #         roles=x[1][1]
# #         hrefs=x[1][0] 
# #         hrefs=hrefs[1::2]
# #     #     voice = [i for i in range(len(X)) if 'voice act' in X[i].lower()]
# # #         notQAorVoice = [0 if ('qa' in X[i].lower() or 'voice act' in X[i].lower()) else 1 for i in range(len(X)) ]
# # #         RolesAndPeople={r:h for r,h in zip(roles[0::2],hrefs[1::2])}

# # #     print([X[i] for i in res])
# # #     print([X[i] for i in QA])
    
# #     break

# %%
# np.sum(notQAorVoice)
# TeamSizes={}
# for k in dictRoles.keys():
#     if len(dictRoles[k][0])>0:
#         TeamSizes[k]=len(np.concatenate(dictRoles[k][0]))
#     else:
#         TeamSizes[k]=0

# %% [markdown]
# ## download prior credits

# %%
it=0
for game,Roles in small_teams.items():
    it+=1;print(it/len(small_teams.items()),end='\r')
    roles=list(Roles.values())
    if len(roles)>0:
        members=np.concatenate(roles)
    else:
        members=[]
#_________________________________________
#_________________________________________
    if it>3:
        creditlinks = members.copy()
        total_urls = len(creditlinks)
        processed_urls = 0
        soup_credits = []

        # Function to process a batch of URLs
        def process_batch(urls):
            global processed_urls
            with ThreadPoolExecutor(max_workers=5) as executor:
                future_to_url = {executor.submit(fetch_and_parse, url): url for url in urls}

                for future in as_completed(future_to_url):
                    soup = future.result()
                    processed_urls += 1
                    if soup:
                        soup_credits.append(str(soup))
                    print(f"Processed {processed_urls}/{total_urls} URLs", end='\r')

        # Split creditlinks into smaller lists of 50 links
        batch_size = 50
        creditlink_batches = [creditlinks[i:i + batch_size] for i in range(0, len(creditlinks), batch_size)]

        # Process each batch sequentially
        for batch in creditlink_batches:
            process_batch(batch)
            time.sleep(5)  # Wait for 3 seconds before retrying

        with open(path_data+'PriorCreditsSoup_'+game.split('/')[-4]+'.pkl', 'wb') as f:
            pickle.dump(soup_credits, f)
# Out:
# Processed 84/84 URLsLs

# %%
# Out:
# 52

# %%
it
# Out:
# 52

# %% [markdown]
# # Plot Past collab network for a game

# %%
for game,Roles in small_teams.items():
    roles=list(Roles.values())
    if len(roles)>0:
        members=np.concatenate(roles)
    else:
        members=[]
#_________________________________________
#_________________________________________
    creditlinks = members.copy()
    with open(path_data+'PriorCreditsSoup_'+game.split('/')[-4]+'.pkl', 'rb') as f:
        soup_credits=pickle.load(f)
    soup_credits = [BeautifulSoup(x, 'html.parser') for x in soup_credits] 
    break
# Out:
# 0.19230769230769232

# %%
empty_soup=0
for game,Roles in small_teams.items():

    with open(path_data+'PriorCreditsSoup_'+game.split('/')[-4]+'.pkl', 'rb') as f:
        soup_credits=pickle.load(f)
    soup_credits = [BeautifulSoup(x, 'html.parser') for x in soup_credits] 
    if len(soup_credits)==0:
        empty_soup+=1

# %%
empty_soup
# Out:
# 17

# %%
52-17
# Out:
# 35

# %%
########################################################## 
##download number of games on which people were credited
##########################################################
hcredits=[];rcredits={}
# creditlinks[0]
for soup_credit,p in zip(soup_credits,creditlinks):
    td_elements = soup_credit.find_all('td')
    td_elements
    # Find all <a> tags within this <td> element
    hcredit=[];rcredit=[]
    for td_element in td_elements:
        a_tags = td_element.find_all('a')

    # Extract the hrefs from each <a> tag
        hcredit.append([a.get('href') for a in a_tags])
        rcredit.append(td_element.get_text().strip())
    hcredits.append(hcredit);rcredits[p]=(rcredit);
# roles[0:257]

# with open(path_career+'soup_credit_'+url.split('/')[-4]+'.pkl', 'wb') as f:
#     pickle.dump(soup_credit, f)

# %%
PriorWorkExp_=np.array([len(rcredits[x])-1 for x in rcredits.keys()])

df = pd.DataFrame(PriorWorkExp_)
df.columns=['prior experience in game dev (number of games)']
# Custom colors
palette = {"Hungary": "#e5f5f9", "Austria": "#2ca25f"}

# Creating the bar chart
ff = 13
aa=3; bb=3; wspace_=0.5; hspace_=0.3
fig = plt.figure(figsize=(aa, bb))
spec = gridspec.GridSpec(ncols=1, nrows=1, width_ratios=[1], wspace=wspace_, hspace=hspace_, height_ratios=[1])

# Figure
ax = fig.add_subplot(spec[0])
ax = sns.histplot(x='prior experience in game dev (number of games)', data=df, palette=palette)
plt.ylabel('number of team members', fontsize=ff)
plt.xlabel("prior experience in game dev (number of games)", fontsize=ff)
plt.title("Game:"+game.split('/')[-4], fontsize=ff)
# plt.ylim(0, max(df['Percentage']) + 5)
sns.despine(offset=10, trim=True)

# Show the plot
# plt.savefig("Baldur's Gate Individual experience.svg",dpi=300, bbox_inches = "tight")
# plt.savefig("Baldur's Gate Individual experience.pdf",dpi=300, bbox_inches = "tight")
# Out:
# <ipython-input-187-2e509ba662ad>:18: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.histplot(x='prior experience in game dev (number of games)', data=df, palette=palette)

# %% [markdown]
# ### Joint Experience

# %%
# Assuming you have the roles data structured as mentioned

roles_data = Roles.copy()
roles_data={k:roles_data[k] for k in roles_data.keys() if len(roles_data[k])>0}
# Reverse mappingfrom person to role
person_to_role = {}
for role, persons in roles_data.items():
    for person in persons:
        person_to_role[person] = role

# Create a list of unique roles
unique_roles = list(roles_data.keys())

# Assign a unique color to each role
colors = list(mcolors.CSS4_COLORS.values())  # Using CSS4 colors
# number of colours to generate
# generate N visually distinct colours
role_to_color = dict(zip(unique_roles, distinctipy.get_colors(len(unique_roles))))
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations
# Reverse mapping from person to role and count roles
person_to_role = {}
role_counts = {}
for role, persons in roles_data.items():
    role_counts[role] = len(persons)
    for person in persons:
        person_to_role[person] = role

# Calculate inverse role frequencies for node sizes
max_count = max(role_counts.values())
role_to_size = {role: (100*max_count / count)**.5 if count>0 else 0 for role, count in role_counts.items()}

def calculate_shared_credits(rcredits):
    # Extract unique credits for each member
    unique_credits = {k: set(v) for k, v in rcredits.items()}

    # Calculate shared credits
    shared_credits = {}
    for (member1, credits1), (member2, credits2) in combinations(unique_credits.items(), 2):
        shared = credits1.intersection(credits2)
        shared_credits[(member1, member2)] = len(shared)

    return shared_credits
shared_credits=calculate_shared_credits(rcredits)

def create_network(shared_credits):
    G = nx.Graph()

    # Add edges with weights
    for (member1, member2), weight in shared_credits.items():
        if weight > MIN_FILTER_COLLABS:  # Add an edge only if there are shared credits
            G.add_edge(member1, member2, weight=weight)

    return G


def build_and_plot_network(person_to_role, role_to_color):
    ff = 13
    aa=8; bb=8; wspace_=0.5; hspace_=0.3
    fig = plt.figure(figsize=(aa, bb))
    spec = gridspec.GridSpec(ncols=1, nrows=1, width_ratios=[1], wspace=wspace_, hspace=hspace_, height_ratios=[1])

    # Figure
    ax = fig.add_subplot(spec[0])
  

    # Build the network
#     G = nx.Graph()
    G = create_network(shared_credits)
    for person in person_to_role:
        G.add_node(person, role=person_to_role[person])
    nodes=list(G.nodes())
    for node in nodes:
        if node not in person_to_role.keys():
            G.remove_node(node)
    # Apply colors to nodes based on roles
    node_colors = [role_to_color[person_to_role[node]] for node in G.nodes()]
    noddesize = [role_to_size[person_to_role[node]] for node in G.nodes()]
    node_colorsdict = {node:role_to_color[person_to_role[node]] for node in G.nodes()}
        
    
    # Plot the network
    pos = nx.spring_layout(G, k=nodedistance, iterations=20)
#     nx.draw(G, pos, node_color=node_colors, with_labels=False, node_size=50, edge_color="gray")

    # Edges
    weights = [(G[u][v]['weight'])**.5 for u, v in G.edges()]
    nx.draw_networkx_edges(G, pos, alpha=0.1, width=weights)

    # Nodes
    nx.draw_networkx_nodes(G, pos, node_color=node_colors,alpha=.7,node_size=noddesize)    
    # Label roles at centroids
    role_positions = {role: np.mean([pos[node] for node in G if person_to_role[node] == role], axis=0) 
                      for role in roles_data.keys()}
    role_colors = {role: [node_colorsdict[node] for node in G if person_to_role[node] == role][0]
                      for role in roles_data.keys()}
    for role, position in role_positions.items():
        col=role_colors[role]
        plt.text(position[0], position[1], role, fontsize=4, ha='center', va='center',color=col)

        
    plt.title("Baldur's gate III: Who worked with who? \nPrior shared game dev experience network of members \n(colored by their role in Baldur's gate III dev team)", fontsize=ff)
    legend_handles = [Patch(color=role_to_color[role], label=role) for role in unique_roles]
    plt.legend(handles=legend_handles,bbox_to_anchor=[1,1,], loc='upper left', title='Roles', fontsize=ff-6,ncol=2)

#     plt.show()
    plt.axis('off')

# Build and plot the network
MIN_FILTER_COLLABS=2
nodedistance=.3
build_and_plot_network(person_to_role, role_to_color)

# plt.savefig("Baldur's Gate III Prior Collabs"+str(MIN_FILTER_COLLABS)+".svg",dpi=500, bbox_inches = "tight")
# plt.savefig("Baldur's Gate III Prior Collabs"+str(MIN_FILTER_COLLABS)+".pdf",dpi=500, bbox_inches = "tight")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-215-b1c62d8daaab> in <module>
#     111 MIN_FILTER_COLLABS=2
#     112 nodedistance=.3
# --> 113 build_and_plot_network(person_to_role, role_to_color)
#     114
#     115 # plt.savefig("Baldur's Gate III Prior Collabs"+str(MIN_FILTER_COLLABS)+".svg",dpi=500, bbox_inches = "tight")
#
# <ipython-input-215-b1c62d8daaab> in build_and_plot_network(person_to_role, role_to_color)
#      94     role_positions = {role: np.mean([pos[node] for node in G if person_to_role[node] == role], axis=0)
#      95                       for role in roles_data.keys()}
# ---> 96     role_colors = {role: [node_colorsdict[node] for node in G if person_to_role[node] == role][0]
#      97                       for role in roles_data.keys()}
#      98     for role, position in role_positions.items():
#
# <ipython-input-215-b1c62d8daaab> in <dictcomp>(.0)
#      94     role_positions = {role: np.mean([pos[node] for node in G if person_to_role[node] == role], axis=0)
#      95                       for role in roles_data.keys()}
# ---> 96     role_colors = {role: [node_colorsdict[node] for node in G if person_to_role[node] == role][0]
#      97                       for role in roles_data.keys()}
#      98     for role, position in role_positions.items():
#
# IndexError: list index out of range

# %%
ff = 13
aa=8; bb=8; wspace_=0.5; hspace_=0.3
fig = plt.figure(figsize=(aa, bb))
spec = gridspec.GridSpec(ncols=1, nrows=1, width_ratios=[1], wspace=wspace_, hspace=hspace_, height_ratios=[1])

# Figure
ax = fig.add_subplot(spec[0])


# Build the network
#     G = nx.Graph()
G = create_network(shared_credits)
for person in person_to_role:
    G.add_node(person, role=person_to_role[person])
nodes=list(G.nodes())
for node in nodes:
    if node not in person_to_role.keys():
        G.remove_node(node)
# Apply colors to nodes based on roles
node_colors = [role_to_color[person_to_role[node]] for node in G.nodes()]
noddesize = [role_to_size[person_to_role[node]] for node in G.nodes()]
node_colorsdict = {node:role_to_color[person_to_role[node]] for node in G.nodes()}


# Plot the network
pos = nx.spring_layout(G, k=nodedistance, iterations=20)
#     nx.draw(G, pos, node_color=node_colors, with_labels=False, node_size=50, edge_color="gray")

# Edges
weights = [(G[u][v]['weight'])**.5 for u, v in G.edges()]
nx.draw_networkx_edges(G, pos, alpha=0.1, width=weights)

# Nodes
nx.draw_networkx_nodes(G, pos, node_color=node_colors,alpha=.7,node_size=noddesize)    
# Label roles at centroids
role_positions = {role: np.mean([pos[node] for node in G if person_to_role[node] == role], axis=0) 
                  for role in roles_data.keys()}
role_colors = {role: [node_colorsdict[node] for node in G if person_to_role[node] == role]
                  for role in roles_data.keys()}
role_colors = {role: role_colors[role][0] if len(role_colors[role])>0 else [0,0,0]
                  for role in role_colors.keys()}
for role, position in role_positions.items():
    col=role_colors[role]
    print(position,role)
    plt.text(position[0], position[1], role, fontsize=4, ha='center', va='center',color=col)


plt.title("Baldur's gate III: Who worked with who? \nPrior shared game dev experience network of members \n(colored by their role in Baldur's gate III dev team)", fontsize=ff)
legend_handles = [Patch(color=role_to_color[role], label=role) for role in unique_roles]
plt.legend(handles=legend_handles,bbox_to_anchor=[1,1,], loc='upper left', title='Roles', fontsize=ff-6,ncol=2)

#     plt.show()
plt.axis('off')
# Out:
# nan A game by
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-217-c9e6fa3b04f6> in <module>
#      43     col=role_colors[role]
#      44     print(position,role)
# ---> 45     plt.text(position[0], position[1], role, fontsize=4, ha='center', va='center',color=col)
#      46
#      47
#
# IndexError: invalid index to scalar variable.

# %%
# for node in G:
#     print(person_to_role[node])
#     if person_to_role[node] == role:
#         print(role, [node_colorsdict[node]  ][0])
roles_data
# Out:
# {'A game by': ['https://www.mobygames.com/person/754603/david-szymanski/'],
#  'Produced by': ['https://www.mobygames.com/person/577863/dave-oshry/'],
#  'Directed by': ['https://www.mobygames.com/person/577863/dave-oshry/'],
#  'With Music by': ['https://www.mobygames.com/person/577900/andrew-hulshult/'],
#  'Lead Dev Support': ['https://www.mobygames.com/person/849108/scott-gurney/'],
#  'Lead QA': ['https://www.mobygames.com/person/955250/cameron-martin/'],
#  'New Blood QA Team': ['https://www.mobygames.com/person/955246/stephen-st-germain/',
#   'https://www.mobygames.com/person/955247/tucker-wilkin/',
#   'https://www.mobygames.com/person/955248/gustav-lindstrom/',
#   'https://www.mobygames.com/person/955249/patrick-gilbert/'],
#  'UI/UX Design': ['https://www.mobygames.com/person/702398/logan-thomas/'],
#  'Voices': ['https://www.mobygames.com/person/577900/andrew-hulshult/',
#   'https://www.mobygames.com/person/955251/natalya-ivanova/',
#   'https://www.mobygames.com/person/577863/dave-oshry/',
#   'https://www.mobygames.com/person/754603/david-szymanski/',
#   'https://www.mobygames.com/person/5693/stephan-weyte/'],
#  'Programming': ['https://www.mobygames.com/person/849108/scott-gurney/'],
#  'Mapping': ['https://www.mobygames.com/person/849108/scott-gurney/',
#   'https://www.mobygames.com/person/955250/cameron-martin/',
#   'https://www.mobygames.com/person/754603/david-szymanski/',
#   'https://www.mobygames.com/person/702398/logan-thomas/',
#   'https://www.mobygames.com/person/955247/tucker-wilkin/'],
#  'Dawn (SDK) Development': ['https://www.mobygames.com/person/955252/ben-moir/'],
#  'Assistant Programming': ['https://www.mobygames.com/person/820065/dillon-rogers/'],
#  'Public Relations': ['https://www.mobygames.com/person/18811/doug-johns/'],
#  'Promotional Material': ['https://www.mobygames.com/person/955250/cameron-martin/',
#   'https://www.mobygames.com/person/955254/christian-pounds/'],
#  'Video Production': ['https://www.mobygames.com/person/955255/richard-james-cook/'],
#  'Official Comic': ['https://www.mobygames.com/person/955256/jacob-mcmanamy/'],
#  'New Blood Admin': ['https://www.mobygames.com/person/955257/randy-morningstar/',
#   'https://www.mobygames.com/person/772519/tomi-niemi/'],
#  'New Blood Family': ['https://www.mobygames.com/person/577905/aaron-alexander/',
#   'https://www.mobygames.com/person/58778/ted-anderson/',
#   'https://www.mobygames.com/person/955258/kate-colvin/',
#   'https://www.mobygames.com/person/680200/jess-damerst/',
#   'https://www.mobygames.com/person/955259/jorge-garza/',
#   'https://www.mobygames.com/person/955260/shaun-hammond/',
#   'https://www.mobygames.com/person/700586/geoff-keene/',
#   'https://www.mobygames.com/person/955261/julia-marchak/',
#   'https://www.mobygames.com/person/955262/jenny-pina/',
#   'https://www.mobygames.com/person/577871/simon-rance/',
#   'https://www.mobygames.com/person/577864/leon-zawada/'],
#  'New Blood Intern': ['https://www.mobygames.com/person/955263/daniel-gilby/'],
#  'Special Thanks': ['https://www.mobygames.com/person/502042/jason-bates/',
#   'https://www.mobygames.com/person/955264/brandi-briner/',
#   'https://www.mobygames.com/person/955265/gb-burford/',
#   'https://www.mobygames.com/person/887171/garrett-cooper/',
#   'https://www.mobygames.com/person/766698/mark-diaz/',
#   'https://www.mobygames.com/person/955266/teah-fortner/',
#   'https://www.mobygames.com/person/634448/megan-fox/',
#   'https://www.mobygames.com/person/955267/lance-green/',
#   'https://www.mobygames.com/person/955273/ryan-green/',
#   'https://www.mobygames.com/person/955268/jessica-harvey/',
#   'https://www.mobygames.com/person/955269/dan-hulshult/',
#   'https://www.mobygames.com/person/955270/karen-hulshult/',
#   'https://www.mobygames.com/person/955271/sander-jansen/',
#   'https://www.mobygames.com/person/955272/ro-kohli/',
#   'https://www.mobygames.com/person/439698/ian-nicholls/',
#   'https://www.mobygames.com/person/162062/jason-oconnell/',
#   'https://www.mobygames.com/person/289168/adam-pyle/',
#   'https://www.mobygames.com/person/710477/joe-radak/',
#   'https://www.mobygames.com/person/955274/brandon-ragsdale/',
#   'https://www.mobygames.com/person/67440/duncan-stanley/',
#   'https://www.mobygames.com/person/955275/evan-szymanski/',
#   'https://www.mobygames.com/person/5272/john-szymanski/',
#   'https://www.mobygames.com/person/955276/rachael-szymanski/',
#   'https://www.mobygames.com/person/654067/terri-vellmann/']}

# %%
# ########################################################## 
# ##download number of games on which people were credited
# ##########################################################

# # URL of the page to scrape
# url=game_links[3]+'credits/windows/'
# # Send a request to the URL
# response = requests.get(url)

# # Check if the request was successful
# if response.status_code == 200:
#     # Parse the content of the page
#     soup = BeautifulSoup(response.content, 'html.parser')
# else:
#     print(f"Failed to retrieve the webpage. Status code: {response.status_code}")


# td_elements = soup.find_all('td')
# th_elements = soup.find_all('th')
# # Find all <a> tags within this <td> element
# hrefs=[];roles=[]
# for td_element in td_elements:
#     a_tags = td_element.find_all('a')
# # Extract the hrefs from each <a> tag
#     hrefs.append([a.get('href') for a in a_tags])
#     roles.append(td_element.get_text().strip())
# # for th_elements in th_elements:
# #     a_tags = th_elements.find_all('a')
# #     hrefs_sections.append([a.get('href') for a in a_tags])

# %% [markdown]
# #

# %% [markdown]
# # Get departments in credits of the game
# - To remove Voice acting, etc,
# - also other studios manually later,
# - construct a list of departments which make sense and
# - automatically assign scores of similarity for each discovered department and then filter

# %%
id_=10
print(list(gamesoup_dict.keys())[id_])
# Out:
# https://www.mobygames.com/game/115902/red-dead-redemption-ii/credits/windows/

# %%
soup= gamesoup_dict[list(gamesoup_dict.keys())[id_]]
th_elements = soup.find_all('th')

print(game_links[id_])

# Assuming 'soup' is a BeautifulSoup object and you need its string representation
X = str(soup)  

# Using list comprehension for efficiency and readability
# loc_th = [[i for i in range(len(X)) if X.startswith(str(th), i)] for th in th_elements]

# loc_th=[]
# for x in th_elements:
#     link_start=str(x) 
#     loc_th.append([i for i in range(len(X)) if X.startswith(link_start, i)])

# td_elements = soup.find_all('td')
# loc_td=[]
# hrefs=[];roles=[]
# # for td_element in td_elements:
# #     a_tags = td_element.find_all('a')
# #     link_start=str(td_element) 
# #     loc_td.append([i for i in range(len(X)) if X.startswith(link_start, i)])
# #     hrefs.append([a.get('href') for a in a_tags])
# #     roles.append(td_element.get_text().strip())
# Out:
# https://www.mobygames.com/game/122190/hades/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-243-ff20dc665348> in <module>
#       8
#       9 # Using list comprehension for efficiency and readability
# ---> 10 loc_th = [[i for i in range(len(X)) if X.startswith(str(th), i)] for th in th_elements]
#      11
#      12 # loc_th=[]
#
# <ipython-input-243-ff20dc665348> in <listcomp>(.0)
#       8
#       9 # Using list comprehension for efficiency and readability
# ---> 10 loc_th = [[i for i in range(len(X)) if X.startswith(str(th), i)] for th in th_elements]
#      11
#      12 # loc_th=[]
#
# <ipython-input-243-ff20dc665348> in <listcomp>(.0)
#       8
#       9 # Using list comprehension for efficiency and readability
# ---> 10 loc_th = [[i for i in range(len(X)) if X.startswith(str(th), i)] for th in th_elements]
#      11
#      12 # loc_th=[]
#
# ~/miniconda3/envs/sos/lib/python3.9/site-packages/bs4/element.py in __unicode__(self)
#    1603     def __unicode__(self):
#    1604         """Renders this PageElement as a Unicode string."""
# -> 1605         return self.decode()
#    1606
#    1607     __str__ = __repr__ = __unicode__
#
# ~/miniconda3/envs/sos/lib/python3.9/site-packages/bs4/element.py in decode(self, indent_level, eventual_encoding, formatter)
#    1700         else:
#    1701             indent_contents = None
# -> 1702         contents = self.decode_contents(
#    1703             indent_contents, eventual_encoding, formatter
#    1704         )
#
# KeyboardInterrupt:

# %%
def SouptoRoles(gamesoup_dict, game_links):
    game_to_priorlinks={}
    RolesAndPeople={}
    for it in range(len(gamesoup_dict)):
        print(it/len(gamesoup_dict),end='\r')
        game,soup = list(gamesoup_dict.items())[it]

        # td_elements = soup.find_all('td')
# # Find all <a> tags within this <td> element
# hrefs=[];roles=[]
# for td_element in td_elements:
#     a_tags = td_element.find_all('a')

# # Extract the hrefs from each <a> tag
#     hrefs.append([a.get('href') for a in a_tags])
#     roles.append(td_element.get_text().strip())

        td_elements = soup.find_all('td')
        hrefs = []
        roles = []

        for td_element in td_elements:
            # Extract 'a' tags, assuming they are direct children of 'td' elements
            a_tags = td_element.find_all('a')
            # Extract href attributes
            hrefs.append([a.get('href') for a in a_tags])
            # Extract text directly
            roles.append(td_element.get_text(strip=True))
        game_to_priorlinks[game]=[roles, hrefs]
        
        RolesAndPeople[game]={r:h for r,h in zip(roles[0::2],hrefs[1::2])}

    return game_to_priorlinks,RolesAndPeople

# %%
gamesoup

# %%
def find_bin(value, bins):
    """
    Find the appropriate bin for the given value using binary search.
    """
    low, high = 0, len(bins) - 1
    while low < high:
        mid = (low + high) // 2
        if value > bins[mid]:
            low = mid + 1
        else:
            high = mid
    return bins[low]

def assign_bins(L, bins):
    """
    Assign each value in L to the appropriate bin.
    """
    bin_assignment = {}
    for value in L:
        bin_assigned = find_bin(value, bins)
        bin_assignment[value] = bin_assigned
    return bin_assignment

# Example usage
loc_td =[x[0] for x in loc_td]
loc_th=np.concatenate(loc_th)
loc_th=list(loc_th)
loc_th.append(max(loc_td)+1)
bin_assignment = assign_bins(loc_td, loc_th)
print(bin_assignment)
# Out:
# {10078: 74208, 10137: 74208, 67106: 74208, 67163: 74208, 67416: 74208, 67492: 74208, 73913: 74208, 73988: 74208, 74283: 78896, 74347: 78896, 74567: 78896, 74634: 78896, 74866: 78896, 74927: 78896, 75138: 78896, 75203: 78896, 75411: 78896, 75470: 78896, 75696: 78896, 75759: 78896, 75976: 78896, 76034: 78896, 76248: 78896, 76307: 78896, 76521: 78896, 76794: 78896, 77077: 78896, 77140: 78896, 77356: 78896, 77428: 78896, 77673: 78896, 77740: 78896, 77972: 78896, 78041: 78896, 78270: 78896, 78339: 78896, 78559: 78896, 78624: 78896, 78835: 78896, 78895: 78896}

# %%
loc_th
# Out:
# array([ 10956,  63456, 109163, 110725, 137679, 144566, 149793, 155043,
#        162447, 195809])

# %%
loc_td

# %%
th_elements
# Out:
# [<th colspan="2"><h4 class="text-center mb-0">Half-Life: Alyx</h4></th>,
#  <th colspan="2"><h4 class="text-center mb-0">The Cast</h4></th>]

# %%
hrefs=hrefs[0:257]
roles=roles[0:257]
RolesAndPeople={r:h for r,h in zip(roles[0::2],hrefs[1::2])}
# with open(path_career+'RolesAndPeople_'+url.split('/')[-4]+'.pkl', 'wb') as f:
#     pickle.dump(RolesAndPeople, f)

# %%
# NUMBER OF TEAM MEMBERS IN GAME DEV  TEAM
len(np.unique(np.concatenate(list(RolesAndPeople.values()))))
# Out:
# 330

# %%
game_devs=np.unique(np.concatenate(list(RolesAndPeople.values())))

# %%
len(game_devs)
# Out:
# 330

# %%
########################################################## 
##download number of games on which people were credited
##########################################################
hcredits=[];rcredits={}
# creditlinks[0]
for soup_credit,p in zip(soup_credits,creditlinks):
    td_elements = soup_credit.find_all('td')
    td_elements
    # Find all <a> tags within this <td> element
    hcredit=[];rcredit=[]
    for td_element in td_elements:
        a_tags = td_element.find_all('a')

    # Extract the hrefs from each <a> tag
        hcredit.append([a.get('href') for a in a_tags])
        rcredit.append(td_element.get_text().strip())
    hcredits.append(hcredit);rcredits[p]=(rcredit);
# roles[0:257]

# with open(path_career+'soup_credit_'+url.split('/')[-4]+'.pkl', 'wb') as f:
#     pickle.dump(soup_credit, f)

# %%
PriorWorkExp_=np.array([len(rcredits[x])-1 for x in rcredits.keys()])



df = pd.DataFrame(PriorWorkExp_)
df.columns=['prior experience in game dev (number of games)']
# Custom colors
 
# Creating the bar chart
ff = 13
aa=3; bb=3; wspace_=0.5; hspace_=0.3
fig = plt.figure(figsize=(aa, bb))
spec = gridspec.GridSpec(ncols=1, nrows=1, width_ratios=[1], wspace=wspace_, hspace=hspace_, height_ratios=[1])

# Figure
ax = fig.add_subplot(spec[0])
ax = sns.histplot(x='prior experience in game dev (number of games)', data=df, palette=palette)
plt.ylabel('number of team members', fontsize=ff)
plt.xlabel("prior experience in game dev (number of games)", fontsize=ff)
plt.title("Game: Baldur's gate III", fontsize=ff)
# plt.ylim(0, max(df['Percentage']) + 5)
sns.despine(offset=10, trim=True)

# Show the plot
# plt.savefig("Baldur's Gate Individual experience.svg",dpi=300, bbox_inches = "tight")
# plt.savefig("Baldur's Gate Individual experience.pdf",dpi=300, bbox_inches = "tight")
# Out:
# <ipython-input-15-a5b88ebac117>:18: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   ax = sns.histplot(x='prior experience in game dev (number of games)', data=df, palette=palette)

# %% [markdown]
# ### Joint Experience

# %%
# Assuming you have the roles data structured as mentioned
roles_data = RolesAndPeople.copy()

# Reverse mappingfrom person to role
person_to_role = {}
for role, persons in roles_data.items():
    for person in persons:
        person_to_role[person] = role

# Create a list of unique roles
unique_roles = list(roles_data.keys())

# Assign a unique color to each role
colors = list(mcolors.CSS4_COLORS.values())  # Using CSS4 colors
# number of colours to generate
# generate N visually distinct colours
role_to_color = dict(zip(unique_roles, distinctipy.get_colors(len(unique_roles))))
import networkx as nx
import matplotlib.pyplot as plt
from itertools import combinations
# Reverse mapping from person to role and count roles
person_to_role = {}
role_counts = {}
for role, persons in roles_data.items():
    role_counts[role] = len(persons)
    for person in persons:
        person_to_role[person] = role

# Calculate inverse role frequencies for node sizes
max_count = max(role_counts.values())
role_to_size = {role: (100*max_count / count)**.5 for role, count in role_counts.items()}

def calculate_shared_credits(rcredits):
    # Extract unique credits for each member
    unique_credits = {k: set(v) for k, v in rcredits.items()}

    # Calculate shared credits
    shared_credits = {}
    for (member1, credits1), (member2, credits2) in combinations(unique_credits.items(), 2):
        shared = credits1.intersection(credits2)
        shared_credits[(member1, member2)] = len(shared)

    return shared_credits
shared_credits=calculate_shared_credits(rcredits)

def create_network(shared_credits):
    G = nx.Graph()

    # Add edges with weights
    for (member1, member2), weight in shared_credits.items():
        if weight > MIN_FILTER_COLLABS:  # Add an edge only if there are shared credits
            G.add_edge(member1, member2, weight=weight)

    return G


def build_and_plot_network(person_to_role, role_to_color):
    ff = 13
    aa=15; bb=15; wspace_=0.5; hspace_=0.3
    fig = plt.figure(figsize=(aa, bb))
    spec = gridspec.GridSpec(ncols=1, nrows=1, width_ratios=[1], wspace=wspace_, hspace=hspace_, height_ratios=[1])

    # Figure
    ax = fig.add_subplot(spec[0])
  

    # Build the network
#     G = nx.Graph()
    G = create_network(shared_credits)
    for person in person_to_role:
        G.add_node(person, role=person_to_role[person])
    nodes=list(G.nodes())
    for node in nodes:
        if node not in person_to_role.keys():
            G.remove_node(node)
    # Apply colors to nodes based on roles
    node_colors = [role_to_color[person_to_role[node]] for node in G.nodes()]
    noddesize = [role_to_size[person_to_role[node]] for node in G.nodes()]
    node_colorsdict = {node:role_to_color[person_to_role[node]] for node in G.nodes()}
        
    
    # Plot the network
    pos = nx.spring_layout(G, k=nodedistance, iterations=20)
#     nx.draw(G, pos, node_color=node_colors, with_labels=False, node_size=50, edge_color="gray")

    # Edges
    weights = [(G[u][v]['weight'])**.5 for u, v in G.edges()]
    nx.draw_networkx_edges(G, pos, alpha=0.1, width=weights)

    # Nodes
    nx.draw_networkx_nodes(G, pos, node_color=node_colors,alpha=.7,node_size=noddesize)    
    # Label roles at centroids
    role_positions = {role: np.mean([pos[node] for node in G if person_to_role[node] == role], axis=0) 
                      for role in roles_data.keys()}
    role_colors = {role: [node_colorsdict[node] for node in G if person_to_role[node] == role][0]
                      for role in roles_data.keys()}
    for role, position in role_positions.items():
        col=role_colors[role]
        plt.text(position[0], position[1], role, fontsize=4, ha='center', va='center',color=col)

        
    plt.title("Baldur's gate III: Who worked with who? \nPrior shared game dev experience network of members \n(colored by their role in Baldur's gate III dev team)", fontsize=ff)
    legend_handles = [Patch(color=role_to_color[role], label=role) for role in unique_roles]
    plt.legend(handles=legend_handles,bbox_to_anchor=[1,1,], loc='upper left', title='Roles', fontsize=ff-6,ncol=2)

#     plt.show()
    plt.axis('off')

# Build and plot the network
MIN_FILTER_COLLABS=2
nodedistance=.3
build_and_plot_network(person_to_role, role_to_color)

# plt.savefig("Baldur's Gate III Prior Collabs"+str(MIN_FILTER_COLLABS)+".svg",dpi=500, bbox_inches = "tight")
# plt.savefig("Baldur's Gate III Prior Collabs"+str(MIN_FILTER_COLLABS)+".pdf",dpi=500, bbox_inches = "tight")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-67-252615d0efab> in <module>
#      15 # number of colours to generate
#      16 # generate N visually distinct colours
# ---> 17 role_to_color = dict(zip(unique_roles, distinctipy.get_colors(len(unique_roles))))
#      18 import networkx as nx
#      19 import matplotlib.pyplot as plt
#
# ~/miniconda3/envs/sos/lib/python3.9/site-packages/distinctipy/distinctipy.py in get_colors(n_colors, exclude_colors, return_excluded, pastel_factor, n_attempts, colorblind_type, rng)
#     288     for i in range(n_colors):
#     289         colors.append(
# --> 290             distinct_color(
#     291                 colors,
#     292                 pastel_factor=pastel_factor,
#
# ~/miniconda3/envs/sos/lib/python3.9/site-packages/distinctipy/distinctipy.py in distinct_color(exclude_colors, pastel_factor, n_attempts, colorblind_type, rng)
#     200
#     201             distance_to_nearest = min(
# --> 202                 [color_distance(compare_color, c) for c in exclude_colors]
#     203             )
#     204
#
# ~/miniconda3/envs/sos/lib/python3.9/site-packages/distinctipy/distinctipy.py in <listcomp>(.0)
#     200
#     201             distance_to_nearest = min(
# --> 202                 [color_distance(compare_color, c) for c in exclude_colors]
#     203             )
#     204
#
# ~/miniconda3/envs/sos/lib/python3.9/site-packages/distinctipy/distinctipy.py in color_distance(c1, c2)
#     116
#     117     mean_r = (r1 + r2) / 2
# --> 118     delta_r = (r1 - r2) ** 2
#     119     delta_g = (g1 - g2) ** 2
#     120     delta_b = (b1 - b2) ** 2
#
# KeyboardInterrupt:
